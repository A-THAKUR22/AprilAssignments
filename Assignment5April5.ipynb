# %% [markdown]
# <a href="https://colab.research.google.com/github/A-THAKUR22/AprilAssignments/blob/main/Assignment5April5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Applying Decision tree classification on the Iris dataset in the sklearn library to predict the species of the flower based on the features given.

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn import svm
import seaborn as sns

# %%
iris_data=load_iris()
iris=pd.DataFrame(data=iris_data.data,columns=iris_data.feature_names)
iris['Species']=iris_data.target

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Species
# 0          0
# ...

# %%
sns.histplot(data=iris,x='sepal length (cm)',hue='Species',kde=True)
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='Count'>

# %%
sns.histplot(data=iris,x='sepal width (cm)',hue='Species',kde=True)
# Out:
# <Axes: xlabel='sepal width (cm)', ylabel='Count'>

# %%
sns.histplot(data=iris,x='petal length (cm)',hue='Species',kde=True)
# Out:
# <Axes: xlabel='petal length (cm)', ylabel='Count'>

# %%
sns.histplot(data=iris,x='petal width (cm)',hue='Species',kde=True)
# Out:
# <Axes: xlabel='petal width (cm)', ylabel='Count'>

# %%
X=iris.drop(columns='Species')
y=iris['Species']

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.8,random_state=42)
treeclf=DecisionTreeClassifier()
treeclf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(15,10))
plot_tree(treeclf,filled=True)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[3] <= 1.55\ngini = 0.651\nsamples = 30\nvalue = [7, 11, 12]'),
#  Text(0.4, 0.5, 'x[3] <= 0.7\ngini = 0.475\nsamples = 18\nvalue = [7, 11, 0]'),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 11\nvalue = [0, 11, 0]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12]')]

# %%
y_pred=treeclf.predict(X_test)
print(f'Predictions of species of the flower : {y_pred}')
# Out:
# Predictions of species of the flower : [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 2 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 2 1 0 0 1 1 2 1 2 1 2 1 0 2 1 0 0 0 1 2 0 0 0 1 0 1 2 0 1 2 0 2 2
#  1 1 2 1 0 1 2 0 0 1 2 0 2 0 0 2 1 2 2 1 2 1 0 0 1 2 0 0 0 1 2 0 2 2 0 1 1
#  2 1 2 0 2 1 2 1 1]

# %%
Accuracy=accuracy_score(y_test,y_pred)
print(f'The accuracy score of our model : {Accuracy}')
# Out:
# The accuracy score of our model : 0.9333333333333333

# %%
ypred2=treeclf.predict(X_train)
acc2=accuracy_score(y_train,ypred2)
acc2
# Out:
# 1.0

# %%
svclf=svm.SVC(kernel='linear')
svclf.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
svpred=svclf.predict(X_test)
svpred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 2, 2, 1, 2, 1, 2, 1, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 1, 0,
#        1, 2, 0, 1, 2, 0, 2, 2, 1, 1, 2, 1, 0, 1, 2, 0, 0, 1, 2, 0, 2, 0,
#        0, 2, 1, 2, 2, 2, 2, 1, 0, 0, 2, 2, 0, 0, 0, 1, 2, 0, 2, 2, 0, 1,
#        1, 2, 1, 2, 0, 2, 1, 2, 1, 1])

# %%
acc3=accuracy_score(y_test,svpred)
acc3
# Out:
# 0.975

# %%
svpred2=svclf.predict(X_train)
acc4=accuracy_score(y_train,svpred2)
acc4
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
randclf=RandomForestClassifier()
randclf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred_for=randclf.predict(X_test)
pred_for
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 2, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 2, 1, 0,
#        0, 1, 1, 2, 1, 2, 1, 2, 1, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 1, 0,
#        1, 2, 0, 1, 2, 0, 2, 2, 1, 1, 2, 1, 0, 1, 2, 0, 0, 1, 2, 0, 2, 0,
#        0, 2, 1, 2, 2, 1, 2, 1, 0, 0, 1, 2, 0, 0, 0, 1, 2, 0, 2, 2, 0, 1,
#        1, 2, 1, 2, 0, 2, 1, 2, 1, 1])

# %%
for_acc=accuracy_score(y_test,pred_for)
for_acc
# Out:
# 0.9333333333333333

# %%
for_pred2=randclf.predict(X_train)
acc5=accuracy_score(y_train,for_pred2)
acc5
# Out:
# 1.0

# %%
from mlxtend.evaluate import bias_variance_decomp

# %%
mse,bias,varaince=bias_variance_decomp(
    estimator=treeclf,
    X_train=X_train.values,
    y_train=y_train.values,
    X_test=X_test.values,
    y_test=y_test.values,
    random_seed=42,
    loss='mse'
    )
print(mse)
print(bias)
print(varaince)
# Out:
# 0.07683333333333334
# 0.048952083333333334
# 0.027881249999999993

# %%
mse,bias,varaince=bias_variance_decomp(
    estimator=svclf,
    X_train=X_train.values,
    y_train=y_train.values,
    X_test=X_test.values,
    y_test=y_test.values,
    random_seed=42,
    loss='mse'
    )
print(mse)
print(bias)
print(varaince)
# Out:
# 0.03366666666666667
# 0.018718333333333337
# 0.014948333333333333

# %%
mse,bias,varaince=bias_variance_decomp(
    estimator=randclf,
    X_train=X_train.values,
    y_train=y_train.values,
    X_test=X_test.values,
    y_test=y_test.values,
    random_seed=42,
    loss='mse'
    )
print(mse)
print(bias)
print(varaince)
# Out:
# 0.06204166666666667
# 0.04527520833333333
# 0.01676645833333333
